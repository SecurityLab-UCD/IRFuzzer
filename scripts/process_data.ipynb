# %%
from typing import Iterable, List, NamedTuple, Tuple
import pandas as pd
import os
from common import subdirs_of

# %%
def convert_percentage_to_float(s: str) -> float:
    return float(s.strip('%')) / 100


def read_experiment_data(path: str) -> pd.DataFrame:
    # the table header is not consistent, so we don't want pandas to detect and process the header (1st row of csv)
    # but let it use the hard-coded column names below.
    return pd.read_csv(
        path,
        index_col=False,
        header=None,
        skiprows=1,
        names=[
            '# relative_time', 'cycles_done', 'cur_item', 'corpus_count', 'pending_total', 'pending_favs', 'bit_cvg',
            'shw_cvg', 'saved_crashes', 'saved_hangs', 'max_depth', 'execs_per_sec', 'total_execs', 'edges_found'
        ],
        converters={
            'bit_cvg': convert_percentage_to_float,
            'shw_cvg': convert_percentage_to_float,
        }
    )

# %%
# for preview purpose only
read_experiment_data(
    '/home/peter/archives/combined/libfuzzer/dagisel/aarch64/0/default/plot_data'
)
# Out:
#        # relative_time  cycles_done  cur_item  corpus_count  pending_total  \
# 0                   61            0         0             9              9
# 1                   66            0         0             9              9
# 2                   71            0         0             9              9
# 3                   76            0         0             9              9
# 4                   81            0         0             9              9
# ...                ...          ...       ...           ...            ...
# 50725           259178            0     21928         23992          21872
# 50726           259184            0     21928         23993          21873
# 50727           259189            0     21928         23993          21873
# 50728           259194            0     21928         23993          21873
# 50729           259196            0     21928         23993          21873
#
#        pending_favs  bit_cvg  shw_cvg  saved_crashes  saved_hangs  max_depth  \
# 0                 1  0.29233  0.00319              0            0          2
# 1                 1  0.29233  0.00319              0            0          2
# 2                 1  0.29233  0.00319              0            0          2
# 3                 1  0.29233  0.00319              0            0          2
# 4                 1  0.29233  0.00319              0            0          2
# ...             ...      ...      ...            ...          ...        ...
# 50725           324  0.79321  0.02574              0            0         27
# 50726           324  0.79323  0.02574              0            0         27
# 50727           324  0.79323  0.02574              0            0         27
# 50728           324  0.79323  0.02574              0            0         27
# 50729           324  0.79323  0.02574              0            0         27
#
#        execs_per_sec  total_execs  edges_found
# 0             225.67        20791        19158
# 1             223.81        21919        19158
# 2             220.54        23039        19158
# 3             220.66        24167        19158
# 4             220.60        25287        19158
# ...              ...          ...          ...
# 50725          67.21     34779453        51984
# 50726          79.58     34779798        51985
# 50727          76.73     34780168        51985
# 50728          69.27     34780512        51985
# 50729          67.23     34780677        51985
#
# [50730 rows x 14 columns]

# %%
# for preview purpose only
read_experiment_data(
    '/home/peter/archives/combined/aflplusplus/dagisel/ve/0/default/plot_data'
)
# Out:
#        # relative_time  cycles_done  cur_item  corpus_count  pending_total  \
# 0                   65            0       643           703            680
# 1                   70            0       609           729            705
# 2                   75            0       377           750            723
# 3                   80            0       377           768            741
# 4                   85            0       719           790            758
# ...                ...          ...       ...           ...            ...
# 50743           259182           17      6403         12376            167
# 50744           259187           17      7964         12376            167
# 50745           259192           17     11735         12376            167
# 50746           259197           17      9455         12376            167
# 50747           259198           17      9455         12376            167
#
#        pending_favs  bit_cvg  shw_cvg  saved_crashes  saved_hangs  max_depth  \
# 0               247   0.1707      0.0              7           19          4
# 1               245   0.1717      0.0             12           19          4
# 2               255   0.1731      0.0             12           19          4
# 3               255   0.1745      0.0             12           19          4
# 4               263   0.1757      0.0             13           19          5
# ...             ...      ...      ...            ...          ...        ...
# 50743             2   0.4087      0.0           1614          177         61
# 50744             2   0.4087      0.0           1614          177         61
# 50745             2   0.4087      0.0           1614          177         61
# 50746             2   0.4087      0.0           1614          177         61
# 50747             2   0.4087      0.0           1614          177         61
#
#        execs_per_sec  total_execs  edges_found
# 0            5149.52       165453        11188
# 1            5859.50       195079        11255
# 2            4322.63       217609        11347
# 3            1648.54       234407        11438
# 4            5245.60       264431        11514
# ...              ...          ...          ...
# 50743        5568.61   1132816346        26784
# 50744        5592.57   1132844290        26784
# 50745        5099.69   1132870860        26784
# 50746        5438.35   1132894801        26784
# 50747        5468.40   1132901311        26784
#
# [50748 rows x 14 columns]

# %%
class Experiment(NamedTuple):
    fuzzer: str
    isel: str
    arch: str
    replicate_id: int
    data: pd.DataFrame


def iterate_over_all_experiments(dir: str, allow_missing_data: bool = False) -> Iterable[Experiment]:
    for fuzzer_dir in subdirs_of(dir):
        fuzzer = fuzzer_dir.name
        for isel_dir in subdirs_of(fuzzer_dir.path):
            isel = isel_dir.name
            for arch_dir in subdirs_of(isel_dir.path):
                arch = arch_dir.name
                for replicate_dir in subdirs_of(arch_dir.path):
                    replicate_id = int(replicate_dir.name)
                    plot_data_path = os.path.join(
                        replicate_dir.path, 'default', 'plot_data'
                    )
                    try:
                        yield Experiment(
                            fuzzer, isel, arch, replicate_id,
                            read_experiment_data(plot_data_path)
                        )
                    except FileNotFoundError:
                        if not allow_missing_data:
                            raise

# %%
def combine_last_row_of_each_experiment_data(experiments: Iterable[Experiment], columns: List[str]) -> pd.DataFrame:
    return pd.DataFrame(
        columns=['fuzzer', 'isel', 'arch', 'replicate', *columns],
        data=(
            [
                exp.fuzzer,
                exp.isel,
                exp.arch,
                exp.replicate_id,
                *exp.data.tail(1)[columns].values.flatten().tolist()
            ]
            for exp in experiments
        )
    )

# %%
df = combine_last_row_of_each_experiment_data(
    iterate_over_all_experiments(
        '/home/peter/archives/combined',
        allow_missing_data=True
    ),
    columns=[
        '# relative_time', 'total_execs',
        'bit_cvg', 'shw_cvg', 'corpus_count'
    ]
)

df
# Out:
#           fuzzer     isel        arch  replicate  # relative_time  \
# 0      libfuzzer  dagisel     aarch64          0         259196.0
# 1      libfuzzer  dagisel     aarch64          1         259196.0
# 2      libfuzzer  dagisel     aarch64          2         259196.0
# 3      libfuzzer  dagisel  aarch64_32          0         259196.0
# 4      libfuzzer  dagisel  aarch64_32          1         259196.0
# ..           ...      ...         ...        ...              ...
# 233  aflplusplus  dagisel          ve          4         259198.0
# 234  aflplusplus  dagisel          ve          1         259198.0
# 235  aflplusplus  dagisel          ve          3         259198.0
# 236  aflplusplus  dagisel          ve          0         259198.0
# 237  aflplusplus  dagisel          ve          2         259198.0
#
#       total_execs  bit_cvg  shw_cvg  corpus_count
# 0    3.478068e+07  0.79323  0.02574       23993.0
# 1    4.188732e+07  0.80125  0.02539       26353.0
# 2    3.677318e+07  0.79765  0.02545       24856.0
# 3    3.486497e+07  0.78960  0.02536       23822.0
# 4    4.159030e+07  0.79477  0.02534       26335.0
# ..            ...      ...      ...           ...
# 233  1.304326e+09  0.50230  0.00000       14804.0
# 234  1.246483e+09  0.42570  0.00000       13496.0
# 235  1.729388e+09  0.50070  0.00000       14037.0
# 236  1.132901e+09  0.40870  0.00000       12376.0
# 237  1.249889e+09  0.40100  0.00000       12226.0
#
# [238 rows x 9 columns]

# %%
df.to_csv('last_row_of_each_experiment.csv', index=False)

# %%
df = pd.read_csv('last_row_of_each_experiment.csv')
df
# Out:
#           fuzzer     isel        arch  replicate  # relative_time  \
# 0      libfuzzer  dagisel     aarch64          0         259196.0
# 1      libfuzzer  dagisel     aarch64          1         259196.0
# 2      libfuzzer  dagisel     aarch64          2         259196.0
# 3      libfuzzer  dagisel  aarch64_32          0         259196.0
# 4      libfuzzer  dagisel  aarch64_32          1         259196.0
# ..           ...      ...         ...        ...              ...
# 233  aflplusplus  dagisel          ve          4         259198.0
# 234  aflplusplus  dagisel          ve          1         259198.0
# 235  aflplusplus  dagisel          ve          3         259198.0
# 236  aflplusplus  dagisel          ve          0         259198.0
# 237  aflplusplus  dagisel          ve          2         259198.0
#
#       total_execs  bit_cvg  shw_cvg
# 0    3.478068e+07  0.79323  0.02574
# 1    4.188732e+07  0.80125  0.02539
# 2    3.677318e+07  0.79765  0.02545
# 3    3.486497e+07  0.78960  0.02536
# 4    4.159030e+07  0.79477  0.02534
# ..            ...      ...      ...
# 233  1.304326e+09  0.50230  0.00000
# 234  1.246483e+09  0.42570  0.00000
# 235  1.729388e+09  0.50070  0.00000
# 236  1.132901e+09  0.40870  0.00000
# 237  1.249889e+09  0.40100  0.00000
#
# [238 rows x 8 columns]

# %%
df_summary = df \
    .drop(columns=['replicate']) \
    .groupby(['fuzzer', 'isel', 'arch']) \
    .agg(['min', 'max', 'count', 'mean', 'std']) \

df_summary
# Out:
#                              # relative_time                            \
#                                          min       max count      mean
# fuzzer    isel    arch
# aflisel   dagisel aarch64            26772.0   61111.0     5   52532.0
#                   aarch64_32         53239.0   61107.0     5   59507.4
#                   aarch64_be         61438.0   61463.0     2   61450.5
#                   amdgcn             61041.0   61106.0     5   61073.4
#                   arm                61437.0   61462.0     2   61449.5
# ...                                      ...       ...   ...       ...
# libfuzzer dagisel systemz           259196.0  259196.0     3  259196.0
#                   thumb             259196.0  259196.0     3  259196.0
#                   ve                259196.0  259196.0     3  259196.0
#                   wasm64            259196.0  259196.0     3  259196.0
#                   x86_64            259196.0  259196.0     3  259196.0
#
#                                            total_execs                    \
#                                        std         min         max count
# fuzzer    isel    arch
# aflisel   dagisel aarch64     14859.079766   3073735.0   7926029.0     5
#                   aarch64_32   3504.236907   6508428.0   7936047.0     5
#                   aarch64_be     17.677670   4586576.0   5630423.0     2
#                   amdgcn         25.774018   3434365.0   3643096.0     5
#                   arm            17.677670   3417376.0   3572457.0     2
# ...                                    ...         ...         ...   ...
# libfuzzer dagisel systemz         0.000000  36585664.0  41392664.0     3
#                   thumb           0.000000  28201702.0  33038491.0     3
#                   ve              0.000000  36203932.0  41075193.0     3
#                   wasm64          0.000000  41261771.0  46116651.0     3
#                   x86_64          0.000000  32822544.0  36105085.0     3
#
#                                                           ...  shw_cvg  \
#                                       mean           std  ...      min
# fuzzer    isel    arch                                    ...
# aflisel   dagisel aarch64     6.540121e+06  1.998673e+06  ...  0.05847
#                   aarch64_32  7.398488e+06  5.729805e+05  ...  0.06296
#                   aarch64_be  5.108500e+06  7.381113e+05  ...  0.06240
#                   amdgcn      3.507550e+06  8.775521e+04  ...  0.00656
#                   arm         3.494916e+06  1.096588e+05  ...  0.04050
# ...                                    ...           ...  ...      ...
# libfuzzer dagisel systemz     3.978549e+07  2.771136e+06  ...  0.25041
#                   thumb       3.118221e+07  2.607017e+06  ...  0.03762
#                   ve          3.939305e+07  2.763242e+06  ...  0.10338
#                   wasm64      4.433396e+07  2.671995e+06  ...  0.05078
#                   x86_64      3.431377e+07  1.661719e+06  ...  0.03164
#
#                                                                 corpus_count  \
#                                   max count      mean       std          min
# fuzzer    isel    arch
# aflisel   dagisel aarch64     0.06435     5  0.062336  0.002435      11134.0
#                   aarch64_32  0.06480     5  0.064038  0.000772      17049.0
#                   aarch64_be  0.06340     2  0.062900  0.000707      14830.0
#                   amdgcn      0.01665     5  0.011034  0.003969      10814.0
#                   arm         0.04210     2  0.041300  0.001131      13129.0
# ...                               ...   ...       ...       ...          ...
# libfuzzer dagisel systemz     0.25526     3  0.252780  0.002427      27890.0
#                   thumb       0.03858     3  0.038063  0.000484      23595.0
#                   ve          0.10539     3  0.104633  0.001093      21003.0
#                   wasm64      0.05202     3  0.051423  0.000621      20121.0
#                   x86_64      0.03302     3  0.032510  0.000757      25050.0
#
#
#                                   max count          mean          std
# fuzzer    isel    arch
# aflisel   dagisel aarch64     19194.0     5  16908.400000  3266.088379
#                   aarch64_32  18839.0     5  18058.800000   647.938037
#                   aarch64_be  18658.0     2  16744.000000  2706.804758
#                   amdgcn      12338.0     5  11371.200000   624.142372
#                   arm         13234.0     2  13181.500000    74.246212
# ...                               ...   ...           ...          ...
# libfuzzer dagisel systemz     29323.0     3  28430.666667   778.539873
#                   thumb       25008.0     3  24305.333333   706.531198
#                   ve          22191.0     3  21750.666667   650.904243
#                   wasm64      21289.0     3  20872.000000   651.707757
#                   x86_64      25401.0     3  25171.666667   198.731813
#
# [72 rows x 25 columns]

# %%
df_summary.to_csv('summary.csv')
